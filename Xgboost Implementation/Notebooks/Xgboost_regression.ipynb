# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/Users/udit/git projects/ML---Implimentations/Xgboost Implementation/Dataset/cardekho_imputated.csv")

# %%
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.shape
# Out:
# (15411, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         15411 non-null  int64
#  1   car_name           15411 non-null  object
#  2   brand              15411 non-null  object
#  3   model              15411 non-null  object
#  4   vehicle_age        15411 non-null  int64
#  5   km_driven          15411 non-null  int64
#  6   seller_type        15411 non-null  object
#  7   fuel_type          15411 non-null  object
#  8   transmission_type  15411 non-null  object
#  9   mileage            15411 non-null  float64
#  10  engine             15411 non-null  int64
#  11  max_power          15411 non-null  float64
#  12  seats              15411 non-null  int64
#  13  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 1.6+ MB

# %%
# Remove Unnecessary Columns
df.drop(columns = ['car_name', 'brand', 'Unnamed: 0'], axis=1, inplace=True)

# %%
df['model'].unique()
# Out:
# array(['Alto', 'Grand', 'i20', 'Ecosport', 'Wagon R', 'i10', 'Venue',
#        'Swift', 'Verna', 'Duster', 'Cooper', 'Ciaz', 'C-Class', 'Innova',
#        'Baleno', 'Swift Dzire', 'Vento', 'Creta', 'City', 'Bolero',
#        'Fortuner', 'KWID', 'Amaze', 'Santro', 'XUV500', 'KUV100', 'Ignis',
#        'RediGO', 'Scorpio', 'Marazzo', 'Aspire', 'Figo', 'Vitara',
#        'Tiago', 'Polo', 'Seltos', 'Celerio', 'GO', '5', 'CR-V',
#        'Endeavour', 'KUV', 'Jazz', '3', 'A4', 'Tigor', 'Ertiga', 'Safari',
#        'Thar', 'Hexa', 'Rover', 'Eeco', 'A6', 'E-Class', 'Q7', 'Z4', '6',
#        'XF', 'X5', 'Hector', 'Civic', 'D-Max', 'Cayenne', 'X1', 'Rapid',
#        'Freestyle', 'Superb', 'Nexon', 'XUV300', 'Dzire VXI', 'S90',
#        'WR-V', 'XL6', 'Triber', 'ES', 'Wrangler', 'Camry', 'Elantra',
#        'Yaris', 'GL-Class', '7', 'S-Presso', 'Dzire LXI', 'Aura', 'XC',
#        'Ghibli', 'Continental', 'CR', 'Kicks', 'S-Class', 'Tucson',
#        'Harrier', 'X3', 'Octavia', 'Compass', 'CLS', 'redi-GO', 'Glanza',
#        'Macan', 'X4', 'Dzire ZXI', 'XC90', 'F-PACE', 'A8', 'MUX',
#        'GTC4Lusso', 'GLS', 'X-Trail', 'XE', 'XC60', 'Panamera', 'Alturas',
#        'Altroz', 'NX', 'Carnival', 'C', 'RX', 'Ghost', 'Quattroporte',
#        'Gurkha'], dtype=object)

# %%
# Getting All Different Type Of Features 
num_features = [feature for feature in df.columns if df[feature].dtype != 'object']
print('no. of Numerical Features :', len(num_features))
cat_features = [feature for feature in df.columns if df[feature].dtype == 'object']
print('no. fo Categorical Features :', len(cat_features))
discrete_features = [feature for feature in num_features if len(df[feature].unique()) < 25]
print('no. of Discrete Feature :', len(discrete_features))
continuous_features = [feature for feature in num_features if feature not in discrete_features]
print('no. of Continuous Feature :', len(continuous_features))
# Out:
# no. of Numerical Features : 7
# no. fo Categorical Features : 4
# no. of Discrete Feature : 2
# no. of Continuous Feature : 5

# %% [markdown]
# # Model Training

# %%
# Independent & Dependent features 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X = df.drop('selling_price', axis=1)
y = df['selling_price']

X['model'] = le.fit_transform(X['model'])

# %%
# create Transformer with 3 Types of Transformers
from sklearn.preprocessing import StandardScaler, OneHotEncoder 
from sklearn.compose import ColumnTransformer 

num_features = X.select_dtypes(exclude='object').columns
ohe_features = ['seller_type','fuel_type','transmission_type']

numeric_transformer = StandardScaler() 
ohe_transformer = OneHotEncoder()

preprocessor = ColumnTransformer(
    [
        ("StandardScaler", numeric_transformer, num_features), 
        ("OneHotEncoder", ohe_transformer, ohe_features)
    ]
)

# %%
X = preprocessor.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
         X, y, test_size=0.25, random_state=42)

X_train.shape, X_test.shape
# Out:
# ((11558, 17), (3853, 17))

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.ensemble import RandomForestRegressor 
from sklearn.linear_model import LinearRegression, Ridge, Lasso 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
# Create a function for Evaluate Model 
def evaluate_model(true, predicted): 
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true,predicted))
    r2_square = r2_score(true,predicted)
    return mae,mse,rmse,r2_square

# %%
# Model Training 
Models = { 
    "Linear Regression" : LinearRegression(),
    "Lasso" : Lasso(),
    "Ridge" : Ridge(),
    "K-Neighbours Regressor" : KNeighborsRegressor(),
    "Decision Tree" : DecisionTreeRegressor(),
    "Random Forest Regressor" : RandomForestRegressor(),
    "SVR" : SVR(),
    "AdaBoost Regressor" : AdaBoostRegressor(),
    "XGBRegressor" : XGBRegressor()
}

# %%
for i in range(len(list(Models))): 
    model = list(Models.values())[i]
    model.fit(X_train,y_train)


    # Make Prediction
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    #Evaluate Train And Test Dataset
    model_train_mae, model_train_mse, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_mse, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    print(list(Models.keys())[i])

    print("Model Performance for Training set")
    print('- Mean Absolute Error : {:.4f}'.format(model_train_mae))
    print('- Mean Squared Error : {:.4f}'.format(model_train_mse))
    print('- Root Mean Squared Error : {:.4f}'.format(model_train_rmse))
    print('- R2 Score : {:.4f}'.format(model_train_r2))

    print('----------------------------------')


    print("Model Performance for Test set")
    print('- Mean Absolute Error : {:.4f}'.format(model_test_mae))
    print('- Mean Squared Error : {:.4f}'.format(model_test_mse))
    print('- Root Mean Squared Error : {:.4f}'.format(model_test_rmse))
    print('- R2 Score : {:.4f}'.format(model_test_r2))

    print("="*50)
    print("\n")
# Out:
# Linear Regression
# Model Performance for Training set
# - Mean Absolute Error : 266675.1076
# - Mean Squared Error : 304874315292.8461
# - Root Mean Squared Error : 552154.2495
# - R2 Score : 0.6220
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 284283.4460
# - Mean Squared Error : 270286925822.7529
# - Root Mean Squared Error : 519891.2635
# - R2 Score : 0.6525
# ==================================================
#
#
# Lasso
# Model Performance for Training set
# - Mean Absolute Error : 266674.4040
# - Mean Squared Error : 304874319723.5829
# - Root Mean Squared Error : 552154.2536
# - R2 Score : 0.6220
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 284283.1476
# - Mean Squared Error : 270286378251.9600
# - Root Mean Squared Error : 519890.7368
# - R2 Score : 0.6525
# ==================================================
#
#
# Ridge
# Model Performance for Training set
# - Mean Absolute Error : 266636.3543
# - Mean Squared Error : 304875057099.0315
# - Root Mean Squared Error : 552154.9213
# - R2 Score : 0.6220
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 284244.2149
# - Mean Squared Error : 270275719516.3194
# - Root Mean Squared Error : 519880.4858
# - R2 Score : 0.6525
# ==================================================
#
#
# K-Neighbours Regressor
# Model Performance for Training set
# - Mean Absolute Error : 91778.3007
# - Mean Squared Error : 109355944177.1933
# - Root Mean Squared Error : 330690.1029
# - R2 Score : 0.8644
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 117774.7015
# - Mean Squared Error : 80481607110.2063
# - Root Mean Squared Error : 283692.8041
# - R2 Score : 0.8965
# ==================================================
#
#
# Decision Tree
# Model Performance for Training set
# - Mean Absolute Error : 4991.7517
# - Mean Squared Error : 426210181.9807
# - Root Mean Squared Error : 20644.8585
# - R2 Score : 0.9995
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 134257.5677
# - Mean Squared Error : 113279781818.1540
# - Root Mean Squared Error : 336570.6194
# - R2 Score : 0.8543
# ==================================================
#
#
# Random Forest Regressor
# Model Performance for Training set
# - Mean Absolute Error : 39510.7171
# - Mean Squared Error : 14537164746.6719
# - Root Mean Squared Error : 120570.1652
# - R2 Score : 0.9820
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 104773.0972
# - Mean Squared Error : 57997511976.2384
# - Root Mean Squared Error : 240826.7260
# - R2 Score : 0.9254
# ==================================================
#
#
# SVR
# Model Performance for Training set
# - Mean Absolute Error : 393336.9862
# - Mean Squared Error : 849881188823.4277
# - Root Mean Squared Error : 921890.0091
# - R2 Score : -0.0538
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 421457.3843
# - Mean Squared Error : 830897090330.6195
# - Root Mean Squared Error : 911535.5672
# - R2 Score : -0.0684
# ==================================================
#
#
# AdaBoost Regressor
# Model Performance for Training set
# - Mean Absolute Error : 347410.6055
# - Mean Squared Error : 203276741656.9472
# - Root Mean Squared Error : 450862.2203
# - R2 Score : 0.7480
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 371544.3698
# - Mean Squared Error : 247458913687.2206
# - Root Mean Squared Error : 497452.4235
# - R2 Score : 0.6818
# ==================================================
#
#
# XGBRegressor
# Model Performance for Training set
# - Mean Absolute Error : 60843.5781
# - Mean Squared Error : 7474499584.0000
# - Root Mean Squared Error : 86455.1883
# - R2 Score : 0.9907
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 100210.4141
# - Mean Squared Error : 75736956928.0000
# - Root Mean Squared Error : 275203.4828
# - R2 Score : 0.9026
# ==================================================

# %%
# Hyperparameter Tuning 
Rf_params = {
    "max_depth" : [5,8,15,None,10], 
    "max_features" : [5,7,"auto",8],
    "min_samples_split" : [2,8,15,20], 
    "n_estimators" : [100,200,500,1000]
}
Xgboost = { 
    "learning_rate" : [0.1,0.01],
    "max_depth" : [5,8,12,20,30], 
    "n_estimators" : [100,200,300], 
    "colsample_bytree" : [0.5,0.8,1,0.3,0.4]
}

# %%
randomcv_models = [
    ("RF", RandomForestRegressor(), Rf_params),
    ("Xgboost", XGBRegressor(), Xgboost)
]

# %%
from sklearn.model_selection import RandomizedSearchCV 

model_params = {}
for name,model,params in randomcv_models: 
    random = RandomizedSearchCV(
        estimator=model,
        param_distributions=params,
        cv = 3,
        n_iter=100,
        verbose=2,
        n_jobs=-1
    )
    random.fit(X_train,y_train)
    model_params[name] = random.best_params_

for model_name in model_params: 
    print(f'-------------------------Best Params from {model_name}---------------------------')
    print(model_params[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=200; total time=   1.2s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   4.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   4.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=500; total time=   4.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=1000; total time=   6.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=1000; total time=   6.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=1000; total time=   6.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=   7.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=   7.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=20, n_estimators=1000; total time=   7.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=500; total time=   3.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=   7.9s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=   7.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=2, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=1000; total time=   8.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=8, min_samples_split=20, n_estimators=500; total time=   3.2s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=500; total time=   2.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=500; total time=   2.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=500; total time=   2.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=500; total time=   3.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=500; total time=   3.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=500; total time=   3.9s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   2.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   2.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=500; total time=   2.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   1.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=2, n_estimators=500; total time=   1.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=500; total time=   3.3s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=500; total time=   3.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=15, n_estimators=500; total time=   3.2s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=1000; total time=   5.8s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=1000; total time=   5.9s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=500; total time=   4.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=500; total time=   4.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=1000; total time=   5.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=8, max_features=5, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=500; total time=   4.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=500; total time=   4.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=500; total time=   3.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=500; total time=   4.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=1000; total time=   6.1s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=500; total time=   1.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=   6.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=   6.4s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=500; total time=   1.5s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=500; total time=   1.5s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=1000; total time=   9.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=1000; total time=   9.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=1000; total time=   6.6s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=15, max_features=8, min_samples_split=8, n_estimators=1000; total time=   9.5s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=8, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   4.5s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   4.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=500; total time=   4.5s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END max_depth=5, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=8, n_estimators=100; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=20, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, max_features=auto, min_samples_split=2, n_estimators=500; total time=   0.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=20, n_estimators=200; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=   5.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=1000; total time=   5.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=500; total time=   7.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=500; total time=   7.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=500; total time=   6.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   1.8s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   1.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=500; total time=   1.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=500; total time=   3.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=500; total time=   3.5s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=1000; total time=   7.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=1000; total time=   7.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=500; total time=   3.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=1000; total time=   7.6s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.5s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=15, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=100; total time=   0.3s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=200; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=200; total time=   0.6s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=8, n_estimators=200; total time=   0.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=1000; total time=  12.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=1000; total time=  12.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=1000; total time=  12.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=500; total time=   2.3s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=100; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=20, n_estimators=500; total time=   2.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=8, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=2, n_estimators=500; total time=   2.1s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=1000; total time=   4.3s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=5, max_features=8, min_samples_split=8, n_estimators=1000; total time=   4.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=500; total time=   3.7s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=15, n_estimators=500; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=1000; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=500; total time=   3.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   2.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=8, n_estimators=500; total time=   3.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   2.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   2.4s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=500; total time=   2.4s
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   0.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   1.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   1.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   0.9s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   1.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   5.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   2.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=20, n_estimators=300; total time=   2.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=20, n_estimators=300; total time=   2.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   2.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   7.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   2.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=20, n_estimators=300; total time=   2.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   2.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   2.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   2.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   2.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   6.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   2.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   2.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   9.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=100; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=100; total time=   0.9s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=100; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=300; total time=  10.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   3.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   3.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   3.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   2.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   2.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=300; total time=   8.5s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=300; total time=   8.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=300; total time=   8.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   2.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   1.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   2.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   2.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   1.8s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=100; total time=   1.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=100; total time=   1.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=300; total time=  10.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=100; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   4.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   5.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   4.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   3.9s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   4.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=20, n_estimators=100; total time=   3.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   8.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   5.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   8.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   8.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   5.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=8, n_estimators=300; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   5.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   1.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=100; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   2.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=100; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   2.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   2.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=300; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   2.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   2.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   2.9s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   3.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   3.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   9.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   9.8s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   9.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   2.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30, n_estimators=100; total time=   0.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30, n_estimators=100; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   4.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=30, n_estimators=100; total time=   0.9s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   3.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   3.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   3.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=200; total time=   4.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   4.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   4.7s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=20, n_estimators=200; total time=   5.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   7.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   7.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=30, n_estimators=200; total time=   7.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   5.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=200; total time=  17.9s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=200; total time=  17.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   5.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=200; total time=  18.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=200; total time=   4.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   4.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   4.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=30, n_estimators=300; total time=   4.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=300; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=30, n_estimators=100; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=30, n_estimators=100; total time=   4.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=30, n_estimators=300; total time=  18.6s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=30, n_estimators=300; total time=  19.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=30, n_estimators=300; total time=  17.1s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   2.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=30, n_estimators=100; total time=   3.8s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.0s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   2.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   0.9s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.9s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   1.2s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   1.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.5s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=300; total time=   1.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   2.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   2.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.1, max_depth=12, n_estimators=100; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=12, n_estimators=300; total time=   1.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   0.9s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=20, n_estimators=300; total time=   3.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=12, n_estimators=200; total time=   1.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=12, n_estimators=200; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=100; total time=   6.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=100; total time=   6.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=100; total time=   6.7s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   8.3s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   8.4s
# [CV] END colsample_bytree=0.8, learning_rate=0.01, max_depth=30, n_estimators=300; total time=   8.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   1.8s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   1.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=20, n_estimators=100; total time=   1.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=300; total time=  14.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=300; total time=  14.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=30, n_estimators=300; total time=  10.9s
# -------------------------Best Params from RF---------------------------
# {'n_estimators': 100, 'min_samples_split': 2, 'max_features': 5, 'max_depth': None}
# -------------------------Best Params from Xgboost---------------------------
# {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.1, 'colsample_bytree': 0.8}

# %%
Models = { 
    "Random Forest Regressor" : RandomForestRegressor(n_estimators = 500, min_samples_split = 2, max_features = 7, max_depth = 15),
    "Xgboost Regressor" : XGBRegressor(n_estimators = 100, max_depth = 5, learning_rate = 0.1, colsample_bytree = 0.8)
}

for i in range(len(list(Models))): 
    model = list(Models.values())[i]
    model.fit(X_train,y_train)


    # Make Prediction
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    #Evaluate Train And Test Dataset
    model_train_mae, model_train_mse, model_train_rmse, model_train_r2 = evaluate_model(y_train, y_train_pred)
    model_test_mae, model_test_mse, model_test_rmse, model_test_r2 = evaluate_model(y_test, y_test_pred)

    print(list(Models.keys())[i])

    print("Model Performance for Training set")
    print('- Mean Absolute Error : {:.4f}'.format(model_train_mae))
    print('- Mean Squared Error : {:.4f}'.format(model_train_mse))
    print('- Root Mean Squared Error : {:.4f}'.format(model_train_rmse))
    print('- R2 Score : {:.4f}'.format(model_train_r2))

    print('----------------------------------')


    print("Model Performance for Test set")
    print('- Mean Absolute Error : {:.4f}'.format(model_test_mae))
    print('- Mean Squared Error : {:.4f}'.format(model_test_mse))
    print('- Root Mean Squared Error : {:.4f}'.format(model_test_rmse))
    print('- R2 Score : {:.4f}'.format(model_test_r2))

    print("="*50)
    print("\n")
# Out:
# Random Forest Regressor
# Model Performance for Training set
# - Mean Absolute Error : 54417.5289
# - Mean Squared Error : 20927710866.6929
# - Root Mean Squared Error : 144664.1312
# - R2 Score : 0.9741
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 100694.5146
# - Mean Squared Error : 52256278879.6275
# - Root Mean Squared Error : 228596.3230
# - R2 Score : 0.9328
# ==================================================
#
#
# Xgboost Regressor
# Model Performance for Training set
# - Mean Absolute Error : 87924.5859
# - Mean Squared Error : 20672094208.0000
# - Root Mean Squared Error : 143777.9337
# - R2 Score : 0.9744
# ----------------------------------
# Model Performance for Test set
# - Mean Absolute Error : 111887.9531
# - Mean Squared Error : 86071615488.0000
# - Root Mean Squared Error : 293379.6440
# - R2 Score : 0.8893
# ==================================================
