# %% [markdown]
# # Simple Linear Regression

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings 

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/Users/udit/git projects/ML---Implimentations/Linear Regression/height-weight.csv")

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
df.shape
# Out:
# (23, 2)

# %%
plt.scatter(x=df['Weight'], y=df['Height'])
plt.xlabel('Weight')
plt.ylabel('Height')
# Out:
# Text(0, 0.5, 'Height')

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
X = df[['Weight']] # Independent feature should be DataFrame or in two 2 Dimentional
y = df['Height'] # This can be series or 1 Dimentional

# %%
print(np.array(X).shape)
print(np.array(y).shape)
# Out:
# (23, 1)
# (23,)

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression() 
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("Coefficent or slope :",model.coef_)
print("Intercept :",model.intercept_)
# Out:
# Coefficent or slope : [17.03440872]
# Intercept : 157.5

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,model.predict(X_train))

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score 
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
score = r2_score(y_test, y_pred)
addjusted_r2 = 1 - (1-score)*(len(y_test) - 1)/(len(y_test)-X_test.shape[1]-1)
print('Score :', score)
print('Addjusted R2 score :', addjusted_r2)
print('mean_absolute_error :', mae)
print('mean_squared_error :', mse)
print('root_mean_squared_error', rmse)
# Out:
# Score : 0.7769869860423441
# Addjusted R2 score : 0.7026493147231254
# mean_absolute_error : 9.822657814519227
# mean_squared_error : 109.77592599051654
# root_mean_squared_error 10.477400726827076

# %% [markdown]
# # OLS Linear Regression

# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from statsmodels) (1.16.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from statsmodels) (2.3.2)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/ml_project/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm 
Ols_model = sm.OLS(y_train,X_train).fit()
prediction = model.predict(X_test)
print(prediction)
# Out:
# [161.08467086 161.08467086 129.3041561  177.45645118 148.56507414]

# %%
print(Ols_model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 Height   R-squared (uncentered):                   0.012
# Model:                            OLS   Adj. R-squared (uncentered):             -0.047
# Method:                 Least Squares   F-statistic:                             0.1986
# Date:                Tue, 14 Oct 2025   Prob (F-statistic):                       0.661
# Time:                        21:32:07   Log-Likelihood:                         -116.62
# No. Observations:                  18   AIC:                                      235.2
# Df Residuals:                      17   BIC:                                      236.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            17.0344     38.226      0.446      0.661     -63.616      97.684
# ==============================================================================
# Omnibus:                        0.849   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.654   Jarque-Bera (JB):                0.661
# Skew:                          -0.428   Prob(JB):                        0.718
# Kurtosis:                       2.614   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Prediction for new data

# %%
model.predict(sc.transform([[70]]))
# Out:
# array([153.38030364])
