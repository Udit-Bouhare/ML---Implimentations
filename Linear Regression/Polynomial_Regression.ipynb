# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
X = 6 * np.random.rand(100, 1) - 3 
y = 0.5 * X**2 + 1.5*X + np.random.randn(100, 1)

# %%
plt.scatter(X, y,color='g')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Synthetic Quadratic Data')
plt.show()

# %%
from sklearn.model_selection import train_test_split 

X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.25, random_state=42)

# %%
from sklearn.linear_model import LinearRegression 
model_1 = LinearRegression() 
model_1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_1.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score 
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
score = r2_score(y_test, y_pred)
addjusted_r2 = 1 - (1-score)*(len(y_test) - 1)/(len(y_test)-X_test.shape[1]-1)
print('Score :', score)
print('Addjusted R2 score :', addjusted_r2)
print('mean_absolute_error :', mae)
print('mean_squared_error :', mse)
print('root_mean_squared_error', rmse)
# Out:
# Score : 0.6659856036930536
# Addjusted R2 score : 0.6514632386362298
# mean_absolute_error : 1.542739219121466
# mean_squared_error : 3.2811157232716948
# root_mean_squared_error 1.811385028996236

# %%
plt.scatter(X_train,y_train)
plt.plot(X_train,model_1.predict(X_train), color = 'r')

# %% [markdown]
# ### NOW BY POLINOMIAL Regression

# %%
from sklearn.preprocessing import PolynomialFeatures 
poly = PolynomialFeatures(degree=2, include_bias=True)

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression 
model_1 = LinearRegression() 
model_1.fit(X_train_poly,y_train)
y_pred = model_1.predict(X_test_poly)

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score 
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
score = r2_score(y_test, y_pred)
addjusted_r2 = 1 - (1-score)*(len(y_test) - 1)/(len(y_test)-X_test.shape[1]-1)
print('Score :', score)
print('Addjusted R2 score :', addjusted_r2)
print('mean_absolute_error :', mae)
print('mean_squared_error :', mse)
print('root_mean_squared_error', rmse)
# Out:
# Score : 0.8860097024712057
# Addjusted R2 score : 0.8810536025786494
# mean_absolute_error : 0.8720000198954453
# mean_squared_error : 1.1197581950283364
# root_mean_squared_error 1.0581862761481724

# %%
print("Coefficent or slopes : ", model_1.coef_)
print("Intercept : ", model_1.intercept_)
# Out:
# Coefficent or slopes :  [[0.         1.55036396 0.53796401]]
# Intercept :  [-0.2041802]

# %%
plt.scatter(X_train,y_train)
plt.scatter(X_train,model_1.predict(X_train_poly))

# %%
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score 
poly = PolynomialFeatures(degree=3, include_bias=True)

X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

model = LinearRegression()
model.fit(X_train_poly,y_train)
y_pred  = model.predict(X_test_poly)

r2_score = r2_score(y_test,y_pred)
print(r2_score)
# Out:
# 0.8840260540957406

# %%
X_new = np.linspace(-3,3,200).reshape(200,1) 
X_new_poly = poly.transform(X_new) 
X_new_poly
# Out:
# (200, 4)

# %%
y_new = model.predict(X_new_poly)
plt.plot(X_new,y_new, "r-", linewidth = 2, label='Predictions')
plt.scatter(X_train,y_train)
plt.scatter(X_test,y_test)
