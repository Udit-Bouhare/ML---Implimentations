# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/Users/udit/git projects/ML---Implimentations/Adaboost Implementation/Dataset/Travel.csv")

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# 0         Deluxe                    3.0        Single            1.0
# 1         Deluxe                    4.0      Divorced            2.0
# 2          Basic                    3.0        Single            7.0
# 3          Basic                    3.0      Divorced            2.0
# 4          Basic                    4.0      Divorced            1.0
#
#    Passport  PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 0         1                       2       1                       0.0
# 1         0                       3       1                       2.0
# 2         1                       3       0                       0.0
# 3         1                       5       1                       1.0
# 4         0                       5       1                       0.0
#
#   Designation  MonthlyIncome
# 0     Manager        20993.0
# 1     Manager        20130.0
# 2   Executive        17090.0
# 3   Executive        17909.0
# 4   Executive        18468.0

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
#  13  NumberOfTrips             4748 non-null   float64
#  14  Passport                  4888 non-null   int64
#  15  PitchSatisfactionScore    4888 non-null   int64
#  16  OwnCar                    4888 non-null   int64
#  17  NumberOfChildrenVisiting  4822 non-null   float64
#  18  Designation               4888 non-null   object
#  19  MonthlyIncome             4655 non-null   float64
# dtypes: float64(7), int64(7), object(6)
# memory usage: 763.9+ KB

# %%
df.shape
# Out:
# (4888, 20)

# %%
# View all the Categorical features
cat_features = [feature for feature in df.columns if df[feature].dtype == 'object']

for feature in cat_features: 
    print(df[feature].value_counts())
    print("-----------------------------")
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64
# -----------------------------
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: count, dtype: int64
# -----------------------------
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64
# -----------------------------
# ProductPitched
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: count, dtype: int64
# -----------------------------
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64
# -----------------------------
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: count, dtype: int64
# -----------------------------

# %%
df['Gender'] = df['Gender'].replace('Fe Male','Female')
df['MaritalStatus'] = df['MaritalStatus'].replace('Single','Unmarried')

# %%
df['Gender'].value_counts(),df['MaritalStatus'].value_counts()
# Out:
# (Gender
#  Male      2916
#  Female    1972
#  Name: count, dtype: int64,
#  MaritalStatus
#  Married      2340
#  Unmarried    1598
#  Divorced      950
#  Name: count, dtype: int64)

# %%
# Columns with missing values
feature_with_na = [feature for feature in df.columns if df[feature].isnull().sum() > 0]

for feature in feature_with_na: 
    print(feature, np.round(df[feature].isnull().mean()* 100, 2))
# Out:
# Age 4.62
# TypeofContact 0.51
# DurationOfPitch 5.14
# NumberOfFollowups 0.92
# PreferredPropertyStar 0.53
# NumberOfTrips 2.86
# NumberOfChildrenVisiting 1.35
# MonthlyIncome 4.77

# %%
# Statistics on numerical columns (Null Cols) 
df[feature_with_na].select_dtypes(exclude='object').describe()
# Out:
#                Age  DurationOfPitch  NumberOfFollowups  PreferredPropertyStar  \
# count  4662.000000      4637.000000        4843.000000            4862.000000
# mean     37.622265        15.490835           3.708445               3.581037
# std       9.316387         8.519643           1.002509               0.798009
# min      18.000000         5.000000           1.000000               3.000000
# 25%      31.000000         9.000000           3.000000               3.000000
# 50%      36.000000        13.000000           4.000000               3.000000
# 75%      44.000000        20.000000           4.000000               4.000000
# max      61.000000       127.000000           6.000000               5.000000
#
#        NumberOfTrips  NumberOfChildrenVisiting  MonthlyIncome
# count    4748.000000               4822.000000    4655.000000
# mean        3.236521                  1.187267   23619.853491
# std         1.849019                  0.857861    5380.698361
# min         1.000000                  0.000000    1000.000000
# 25%         2.000000                  1.000000   20346.000000
# 50%         3.000000                  1.000000   22347.000000
# 75%         4.000000                  2.000000   25571.000000
# max        22.000000                  3.000000   98678.000000

# %% [markdown]
# #### Handling missing values

# %%
# Impute NaN Values 
fill_with_median = ['Age','DurationOfPitch','NumberOfTrips','MonthlyIncome']
fill_with_mode = ['TypeofContact','NumberOfFollowups','PreferredPropertyStar','NumberOfChildrenVisiting']

for feature in fill_with_mode: 
    df[feature] = df[feature].fillna(df[feature].mode()[0])
for feature in fill_with_median: 
    df[feature] = df[feature].fillna(df[feature].median())

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# #### Drop Features

# %%
df.drop('CustomerID', axis=1, inplace=True)

# %% [markdown]
# ### **Feature Engineering**
# #### Feature Exraction

# %%
# create a new column for feature 
df['TotalVisiting'] = df['NumberOfPersonVisiting'] + df['NumberOfChildrenVisiting']
df.drop(columns=['NumberOfPersonVisiting','NumberOfChildrenVisiting'], axis=1, inplace=True)

# %%
# all type of features
num_features = [feature for feature in df.columns if df[feature].dtype != 'object']
print("no of numerical Features : ", len(num_features))
cat_features = [feature for feature in df.columns if df[feature].dtype == 'object']
print("no of categorical features : ", len(cat_features))
discreate_features = [feature for feature in num_features if len(df[feature].unique()) < 25]
print("no of discreate features : ", len(discreate_features))
continuous_features = [feature for feature in num_features if feature not in discreate_features]
print("no of continuous features : ", len(continuous_features))
# Out:
# no of numerical Features :  12
# no of categorical features :  6
# no of discreate features :  9
# no of continuous features :  3

# %%
df.head()
# Out:
#    ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0          1  41.0     Self Enquiry         3              6.0
# 1          0  49.0  Company Invited         1             14.0
# 2          1  37.0     Self Enquiry         1              8.0
# 3          0  33.0  Company Invited         1              9.0
# 4          0  36.0     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfFollowups ProductPitched  \
# 0        Salaried  Female                3.0         Deluxe
# 1        Salaried    Male                4.0         Deluxe
# 2     Free Lancer    Male                4.0          Basic
# 3        Salaried  Female                3.0          Basic
# 4  Small Business    Male                3.0          Basic
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                    3.0     Unmarried            1.0         1
# 1                    4.0      Divorced            2.0         0
# 2                    3.0     Unmarried            7.0         1
# 3                    3.0      Divorced            2.0         1
# 4                    4.0      Divorced            1.0         0
#
#    PitchSatisfactionScore  OwnCar Designation  MonthlyIncome  TotalVisiting
# 0                       2       1     Manager        20993.0            3.0
# 1                       3       1     Manager        20130.0            5.0
# 2                       3       0   Executive        17090.0            3.0
# 3                       5       1   Executive        17909.0            3.0
# 4                       5       1   Executive        18468.0            2.0

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split 
X = df.drop('ProdTaken', axis=1) 
y = df['ProdTaken']

# %%
cat_features = X.select_dtypes(include='object').columns
num_features = X.select_dtypes(exclude='object').columns 

for col in cat_features: 
    X[col] = X[col].astype(str).str.strip().str.lower()

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder 
from sklearn.compose import ColumnTransformer 

numeric_transformer = StandardScaler()
ohe_encoder = OneHotEncoder(drop='first') 

preprocessor = ColumnTransformer(
    [
        ("StandardScaler", numeric_transformer, num_features),
        ("OneHotencoder", ohe_encoder, cat_features)
    ]
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.25, random_state=42)

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression 
from sklearn.naive_bayes import GaussianNB 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.svm import SVC 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
def evaluate_matrix(true, predicted): 
    Score = accuracy_score(true,predicted)
    precision = precision_score(true, predicted)
    recall = recall_score(true,predicted)
    f1 = f1_score(true,predicted)
    roc_auc = roc_auc_score(true,predicted)
    return Score, precision, recall, f1, roc_auc

# %%
Models = { 
    'LogisticRegression' : LogisticRegression(),
    'GaussianNB' : GaussianNB(),
    'DecisionTree' : DecisionTreeClassifier(),
    'KNeighbours' : KNeighborsClassifier(),
    'SVC' : SVC(),
    'RandomForest' : RandomForestClassifier(),
    'AdaBoost' : AdaBoostClassifier(),
    'GradientBosst' : GradientBoostingClassifier()
}

# %%
for i in range(len(list(Models))): 
    model = list(Models.values())[i]
    model.fit(X_train,y_train)

    # Make Prediction 
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Evaluate Train And Test Dataset 
    model_train_Score, model_train_precision, model_train_recall, model_train_f1, model_train_roc_auc = evaluate_matrix(y_train,y_train_pred)
    model_test_Score, model_test_precision, model_test_recall, model_test_f1, model_test_roc_auc = evaluate_matrix(y_test,y_test_pred)

    print(list(Models.keys())[i])

    print("Model Performance Training Set")
    print('-Accuracy Score : {:.4f}'.format(model_train_Score))
    print('-Precision : {:.4f}'.format(model_train_precision))
    print('-Recall : {:.4f}'.format(model_train_recall))
    print('-f1 Score: {:.4f}'.format(model_train_f1))
    print('-ROC AUC Score : {:.4f}'.format(model_train_roc_auc))

    print('-------------------------------------------')

    print("Model Performance Test Set")
    print('-Accuracy Score : {:.4f}'.format(model_test_Score))
    print('-Precision : {:.4f}'.format(model_test_precision))
    print('-Recall : {:.4f}'.format(model_test_recall))
    print('-f1 Score: {:.4f}'.format(model_test_f1))
    print('-ROC AUC Score : {:.4f}'.format(model_test_roc_auc))

    print("="*50)
    print("\n")
# Out:
# LogisticRegression
# Model Performance Training Set
# -Accuracy Score : 0.8432
# -Precision : 0.7061
# -Recall : 0.2999
# -f1 Score: 0.4209
# -ROC AUC Score : 0.6353
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.8445
# -Precision : 0.6571
# -Recall : 0.3094
# -f1 Score: 0.4207
# -ROC AUC Score : 0.6367
# ==================================================
#
#
# GaussianNB
# Model Performance Training Set
# -Accuracy Score : 0.7065
# -Precision : 0.3552
# -Recall : 0.6671
# -f1 Score: 0.4636
# -ROC AUC Score : 0.6914
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.6997
# -Precision : 0.3414
# -Recall : 0.6951
# -f1 Score: 0.4579
# -ROC AUC Score : 0.6979
# ==================================================
#
#
# DecisionTree
# Model Performance Training Set
# -Accuracy Score : 1.0000
# -Precision : 1.0000
# -Recall : 1.0000
# -f1 Score: 1.0000
# -ROC AUC Score : 1.0000
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.9043
# -Precision : 0.7366
# -Recall : 0.7399
# -f1 Score: 0.7383
# -ROC AUC Score : 0.8404
# ==================================================
#
#
# KNeighbours
# Model Performance Training Set
# -Accuracy Score : 0.9424
# -Precision : 0.9278
# -Recall : 0.7561
# -f1 Score: 0.8332
# -ROC AUC Score : 0.8711
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.8944
# -Precision : 0.8133
# -Recall : 0.5471
# -f1 Score: 0.6542
# -ROC AUC Score : 0.7595
# ==================================================
#
#
# SVC
# Model Performance Training Set
# -Accuracy Score : 0.8983
# -Precision : 0.9197
# -Recall : 0.5093
# -f1 Score: 0.6556
# -ROC AUC Score : 0.7494
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.8740
# -Precision : 0.8416
# -Recall : 0.3812
# -f1 Score: 0.5247
# -ROC AUC Score : 0.6826
# ==================================================
#
#
# RandomForest
# Model Performance Training Set
# -Accuracy Score : 1.0000
# -Precision : 1.0000
# -Recall : 1.0000
# -f1 Score: 1.0000
# -ROC AUC Score : 1.0000
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.9296
# -Precision : 0.9477
# -Recall : 0.6502
# -f1 Score: 0.7713
# -ROC AUC Score : 0.8211
# ==================================================
#
#
# AdaBoost
# Model Performance Training Set
# -Accuracy Score : 0.8391
# -Precision : 0.7488
# -Recall : 0.2310
# -f1 Score: 0.3531
# -ROC AUC Score : 0.6064
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.8396
# -Precision : 0.6753
# -Recall : 0.2332
# -f1 Score: 0.3467
# -ROC AUC Score : 0.6041
# ==================================================
#
#
# GradientBosst
# Model Performance Training Set
# -Accuracy Score : 0.8895
# -Precision : 0.8724
# -Recall : 0.4907
# -f1 Score: 0.6281
# -ROC AUC Score : 0.7369
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.8723
# -Precision : 0.7863
# -Recall : 0.4126
# -f1 Score: 0.5412
# -ROC AUC Score : 0.6938
# ==================================================

# %%
# Hyperparameter Tuning 
Knn_params = {'n_neighbors': [2, 3, 4, 5, 6, 7, 8, 10, 20]}
GradientBoost_params = {
    "loss" : ['log_loss', 'exponential'],
    'criterion' : ['friedman_mse', 'squared_error'],
    "min_samples_split" : [2,8,15,20], 
    "n_estimators" : [100,200,500,1000],
    "max_depth" : [5,8,15,None,10]
}

# %%
# model list for hyperparameter tuning 
randomcv_models = [
    ("KNN", KNeighborsClassifier(), Knn_params),
    ('GradientBoost', GradientBoostingClassifier(), GradientBoost_params)
]

# %%
from sklearn.model_selection import RandomizedSearchCV 

model_params = {}
for name,model,params in randomcv_models: 
    random = RandomizedSearchCV(estimator=model,
                                param_distributions=params,
                                n_iter=100,
                                cv=3,
                                verbose=2,
                                n_jobs=-1)
    random.fit(X_train,y_train)
    model_params[name] = random.best_params_

for model_name in model_params: 
    print(f'----------------------Best Params for {model_name}--------------------')
    print(model_params[model_name])
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=8; total time=   0.0s
# [CV] END ......................................n_neighbors=8; total time=   0.0s
# [CV] END ......................................n_neighbors=8; total time=   0.0s
# [CV] END .....................................n_neighbors=10; total time=   0.0s
# [CV] END .....................................n_neighbors=10; total time=   0.0s
# [CV] END .....................................n_neighbors=10; total time=   0.0s
# [CV] END .....................................n_neighbors=20; total time=   0.0s
# [CV] END .....................................n_neighbors=20; total time=   0.0s
# [CV] END .....................................n_neighbors=20; total time=   0.0s
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=500; total time=   4.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=500; total time=   4.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=100; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=100; total time=   2.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=100; total time=   2.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=200; total time=   2.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=200; total time=   4.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=200; total time=   4.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=200; total time=   4.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=100; total time=   1.8s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=8, n_estimators=200; total time=   1.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=8, n_estimators=200; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=200; total time=   4.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=100; total time=   1.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=8, n_estimators=200; total time=   1.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=100; total time=   1.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=100; total time=   1.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=100; total time=   1.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=200; total time=   3.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=100; total time=   1.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=100; total time=   1.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=100; total time=   1.7s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=200; total time=   1.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=200; total time=   1.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=200; total time=   1.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=200; total time=   2.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=500; total time=   5.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=500; total time=   5.4s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=500; total time=   4.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=20, n_estimators=200; total time=   1.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=20, n_estimators=200; total time=   1.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=500; total time=   4.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=20, n_estimators=200; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=100; total time=   1.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=100; total time=   1.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=100; total time=   1.8s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=500; total time=   5.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=500; total time=   4.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=200; total time=   2.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=200; total time=   2.7s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=8, n_estimators=1000; total time=   5.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=8, n_estimators=1000; total time=   5.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=8, n_estimators=1000; total time=   5.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=500; total time=   5.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=500; total time=   6.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=500; total time=   6.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=200; total time=   2.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=100; total time=   0.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=100; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=100; total time=   1.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   5.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   6.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   5.7s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=1000; total time=   5.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=1000; total time=   6.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=1000; total time=   5.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=500; total time=   4.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=500; total time=   3.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=500; total time=   5.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=500; total time=   6.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=500; total time=   6.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   7.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   8.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   8.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=500; total time=   5.7s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=200; total time=   1.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=200; total time=   1.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   8.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=200; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   8.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=200; total time=   3.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=200; total time=   3.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=200; total time=   3.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=20, n_estimators=1000; total time=   7.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   8.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   7.8s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   7.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   8.7s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   8.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=200; total time=   4.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=200; total time=   6.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=200; total time=   6.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=200; total time=   4.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=200; total time=   6.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   3.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=200; total time=   4.8s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   7.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   3.7s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=200; total time=   3.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=200; total time=   3.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=20, n_estimators=200; total time=   3.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   4.9s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=200; total time=   6.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=200; total time=   5.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=200; total time=   6.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=20, n_estimators=100; total time=   1.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   6.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   6.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=1000; total time=   7.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=1000; total time=   7.7s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   6.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=1000; total time=   8.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=200; total time=   2.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=200; total time=   2.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   4.8s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=200; total time=   2.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   3.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   5.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=200; total time=   2.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=200; total time=   2.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=500; total time=   5.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   6.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=500; total time=   5.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   6.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   6.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=500; total time=   5.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=10, min_samples_split=8, n_estimators=200; total time=   3.1s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   7.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=500; total time=   5.5s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=500; total time=   5.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   6.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=2, n_estimators=500; total time=   6.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=1000; total time=   7.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=500; total time=   7.6s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=500; total time=   8.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=200; total time=   4.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=200; total time=   4.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=200; total time=   4.7s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=500; total time=   8.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=2, n_estimators=1000; total time=   6.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=2, n_estimators=1000; total time=   7.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=2, n_estimators=1000; total time=   7.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   6.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   6.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=500; total time=   8.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=500; total time=   8.0s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=20, n_estimators=500; total time=   8.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=8, n_estimators=1000; total time=   5.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=1000; total time=   6.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=1000; total time=   6.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=2, n_estimators=1000; total time=   6.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.4s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=20, n_estimators=200; total time=   2.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   2.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   2.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   5.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=100; total time=   0.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   5.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=8, n_estimators=100; total time=   0.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=20, n_estimators=500; total time=   5.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=20, n_estimators=500; total time=   5.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=20, n_estimators=500; total time=   5.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=2, n_estimators=100; total time=   1.4s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=15, n_estimators=1000; total time=   6.2s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=15, n_estimators=1000; total time=   6.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=10, min_samples_split=15, n_estimators=1000; total time=   6.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   6.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   6.7s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=15, n_estimators=100; total time=   2.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=8, n_estimators=1000; total time=   6.8s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=100; total time=   2.9s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=15, n_estimators=100; total time=   1.4s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=15, n_estimators=100; total time=   1.4s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=10, min_samples_split=15, n_estimators=100; total time=   1.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=500; total time=   6.2s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=100; total time=   2.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=100; total time=   2.8s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=500; total time=   6.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=500; total time=   6.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=8, n_estimators=200; total time=   2.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=8, n_estimators=200; total time=   2.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=500; total time=   5.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=500; total time=   5.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=8, min_samples_split=8, n_estimators=200; total time=   2.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=500; total time=   5.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=200; total time=   5.6s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=200; total time=   5.7s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=None, min_samples_split=15, n_estimators=200; total time=   5.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=200; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=8, min_samples_split=15, n_estimators=200; total time=   2.1s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=1000; total time=   8.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=500; total time=   6.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=1000; total time=   6.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=500; total time=   6.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=20, n_estimators=500; total time=   6.3s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=1000; total time=   7.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   6.1s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   3.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   3.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=200; total time=   4.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=200; total time=   4.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=15, min_samples_split=15, n_estimators=200; total time=   4.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   6.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   6.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=5, min_samples_split=20, n_estimators=500; total time=   3.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   3.0s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   2.8s
# [CV] END criterion=squared_error, loss=exponential, max_depth=None, min_samples_split=8, n_estimators=100; total time=   3.1s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=15, n_estimators=200; total time=   4.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=15, n_estimators=200; total time=   3.9s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=15, n_estimators=200; total time=   4.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=500; total time=   3.7s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   6.5s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   6.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=20, n_estimators=100; total time=   1.8s
# [CV] END criterion=friedman_mse, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=1000; total time=   6.7s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=20, n_estimators=100; total time=   2.0s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=20, n_estimators=100; total time=   1.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   7.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   7.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.6s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=None, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END criterion=squared_error, loss=exponential, max_depth=10, min_samples_split=2, n_estimators=1000; total time=   6.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=100; total time=   2.5s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=100; total time=   2.5s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   3.9s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.3s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   5.0s
# [CV] END criterion=squared_error, loss=log_loss, max_depth=15, min_samples_split=2, n_estimators=1000; total time=   5.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=15, min_samples_split=8, n_estimators=100; total time=   2.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=5, min_samples_split=20, n_estimators=1000; total time=   6.5s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=1000; total time=   6.1s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=1000; total time=   6.8s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   7.4s
# [CV] END criterion=squared_error, loss=exponential, max_depth=8, min_samples_split=8, n_estimators=1000; total time=   7.2s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   7.6s
# [CV] END criterion=friedman_mse, loss=log_loss, max_depth=None, min_samples_split=20, n_estimators=1000; total time=   7.8s
# ----------------------Best Params for KNN--------------------
# {'n_neighbors': 3}
# ----------------------Best Params for GradientBoost--------------------
# {'n_estimators': 1000, 'min_samples_split': 15, 'max_depth': 10, 'loss': 'exponential', 'criterion': 'friedman_mse'}

# %%
Models = { 
    'KNeighbours' : KNeighborsClassifier(n_neighbors = 3),
    'GradientBosst' : GradientBoostingClassifier(n_estimators = 1000, min_samples_split = 15, max_depth = 10, loss = 'exponential', criterion = 'friedman_mse')
}


for i in range(len(list(Models))): 
    model = list(Models.values())[i]
    model.fit(X_train,y_train)

    # Make Prediction 
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # Evaluate Train And Test Dataset 
    model_train_Score, model_train_precision, model_train_recall, model_train_f1, model_train_roc_auc = evaluate_matrix(y_train,y_train_pred) 
    model_test_Score, model_test_precision, model_test_recall, model_test_f1, model_test_roc_auc = evaluate_matrix(y_test,y_test_pred) 

    print(list(Models.keys())[i])

    print("Model Performance Training Set")
    print('-Accuracy Score : {:.4f}'.format(model_train_Score))
    print('-Precision : {:.4f}'.format(model_train_precision))
    print('-Recall : {:.4f}'.format(model_train_recall))
    print('-f1 Score: {:.4f}'.format(model_train_f1))
    print('-ROC AUC Score : {:.4f}'.format(model_train_roc_auc))

    print('-------------------------------------------')

    print("Model Performance Test Set")
    print('-Accuracy Score : {:.4f}'.format(model_test_Score))
    print('-Precision : {:.4f}'.format(model_test_precision))
    print('-Recall : {:.4f}'.format(model_test_recall))
    print('-f1 Score: {:.4f}'.format(model_test_f1))
    print('-ROC AUC Score : {:.4f}'.format(model_test_roc_auc))

    print("="*50)
    print("\n")
# Out:
# KNeighbours
# Model Performance Training Set
# -Accuracy Score : 0.9722
# -Precision : 0.9447
# -Recall : 0.9067
# -f1 Score: 0.9253
# -ROC AUC Score : 0.9471
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.9165
# -Precision : 0.8306
# -Recall : 0.6816
# -f1 Score: 0.7488
# -ROC AUC Score : 0.8253
# ==================================================
#
#
# GradientBosst
# Model Performance Training Set
# -Accuracy Score : 1.0000
# -Precision : 1.0000
# -Recall : 1.0000
# -f1 Score: 1.0000
# -ROC AUC Score : 1.0000
# -------------------------------------------
# Model Performance Test Set
# -Accuracy Score : 0.9566
# -Precision : 0.9670
# -Recall : 0.7892
# -f1 Score: 0.8691
# -ROC AUC Score : 0.8916
# ==================================================

# %%
# Plot ROC AUC CURVE 
# Define your models
models = [
    {"label": "K Neighbors", "model" : KNeighborsClassifier(n_neighbors = 3)},
    {"label": "GradientBoost", "model": GradientBoostingClassifier(n_estimators = 1000, min_samples_split = 15, max_depth = 10, loss = 'exponential', criterion = 'friedman_mse')}
]

plt.figure(figsize=(8, 6))

# Loop through models
for algo in models:
    model = algo['model']
    model.fit(X_train, y_train)  # train model
    
    # Predict probabilities for positive class
    y_prob = model.predict_proba(X_test)[:, 1]
    
    # Compute FPR, TPR
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    
    # Calculate AUC
    auc_score = roc_auc_score(y_test, y_prob)
    
    # Plot ROC curve
    plt.plot(fpr, tpr, label=f"{algo['label']} ROC (AUC = {auc_score:.2f})")

# Plot reference line for random guessing
plt.plot([0, 1], [0, 1], 'r--')

# Customize plot
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (1-Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.title('ROC Curve Comparison')
plt.legend(loc="lower right")

plt.savefig("roc_comparison.png")
plt.show()
